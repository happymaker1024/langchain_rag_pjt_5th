# %% [markdown]
# ## 케글의 와인 데이터

# %% [markdown]
# - https://www.kaggle.com/datasets/zynicide/wine-reviews

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)

PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
OPENAI_EMBEDDING_MODEL = os.getenv("OPENAI_EMBEDDING_MODEL")
PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_NAMESPACE = os.getenv("PINECONE_NAMESPACE")

# %% [markdown]
# ## document loader

# %%
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader('./wine_reviews/winemag-data-130k-v2.csv')
docs = loader.load()
for i, d in enumerate(docs[:2]):
    print(i, d)
# Out:
# 0 page_content=': 0
# country: Italy
# description: Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.
# designation: Vulkà Bianco
# points: 87
# price:
# province: Sicily & Sardinia
# region_1: Etna
# region_2:
# taster_name: Kerin O’Keefe
# taster_twitter_handle: @kerinokeefe
# title: Nicosia 2013 Vulkà Bianco  (Etna)
# variety: White Blend
# winery: Nicosia' metadata={'source': './wine_reviews/winemag-data-130k-v2.csv', 'row': 0}
# 1 page_content=': 1
# country: Portugal
# description: This is ripe and fruity, a wine that is smooth while still structured. Firm tannins are filled out with juicy red berry fruits and freshened with acidity. It's  already drinkable, although it will certainly be better from 2016.
# designation: Avidagos
# points: 87
# price: 15.0
# province: Douro
# region_1:
# region_2:
# taster_name: Roger Voss
# taster_twitter_handle: @vossroger
# title: Quinta dos Avidagos 2011 Avidagos Red (Douro)
# variety: Portuguese Red
# winery: Quinta dos Avidagos' metadata={'source': './wine_reviews/winemag-data-130k-v2.csv', 'row': 1}

# %%
len(docs)
# Out:
# 129971

# %% [markdown]
# # embedding 모델 객체 생성

# %%
# embedding 모델 객체 생성
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model=OPENAI_EMBEDDING_MODEL)

# %% [markdown]
# # Pinecone객체, index객체 생성

# %%
from pinecone import Pinecone, ServerlessSpec


# Pinecone 클라이언트를 초기화(객체생성)
pc = Pinecone(api_key=PINECONE_API_KEY)

# %% [markdown]
# - index 있으면 삭제

# %%
# index_name = PINECONE_INDEX_NAME

# for idx in pc.list_indexes():
#     if idx.name == index_name:
#         pc.delete_index(index_name)

# %% [markdown]
# - Pinecone 객체 생성, index 생성

# %%
# pinecone에 index list 가져오기
existing_indexes = pc.list_indexes()

# 이름만 추출
index_names = [index['name'] for index in existing_indexes.indexes]
# print(index_names)

# index 이름이 존재 하지 않으면 생성
if PINECONE_INDEX_NAME not in index_names:
    pc.create_index(
        name=PINECONE_INDEX_NAME,
        dimension=1536,  # 모델 차원, openapi embeding model을 사용함. 정확하게 일치
        metric="cosine",  # 모델 메트릭, openapi embeding model 에서 사용하는 것 확인
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )
    print(f"Index '{PINECONE_INDEX_NAME}' created successfully.")
else:
    print(f"Index '{PINECONE_INDEX_NAME}' already exists.")
# Out:
# Index 'wine-reviews' created successfully.

# %% [markdown]
# - 업로딩에 기간이 좀 걸림, 경우에 따라 50분 정도 걸림
# - pinecone 월간 쓰기 작업 제한(Write Unit Limit)을 초과하면 더이상 업로딩을 못함

# %% [markdown]
# # Split 객체 생성

# %%
# split하기
from langchain.text_splitter import RecursiveCharacterTextSplitter

# 텍스트 분할기 설정 (예: 1000자씩 분할)
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, 
    chunk_overlap=100,
    # length_function=tiktoken_len,  # 토큰 기반 길이 측정    
    length_function=len,  # 문자수   
    separators=["\n\n", "\n", " ", ""]
    )

# 문서를 분할
chunks = text_splitter.split_documents(docs)

# %%
len(chunks)
# Out:
# 129982

# %% [markdown]
# # 배치 크기 단위로 저장하기

# %% [markdown]
# - langchain_pinecone 으로 벡터 DB에 저장

# %%
# vector sotre에 저장(2시간정도 걸림)
from langchain_pinecone import PineconeVectorStore

batch_size = 100  # 한 번에 처리할 문서 수(최대 vector 수 1000개, 2MB 이내)

for i in range(0, len(chunks), batch_size):
    batch_docs = chunks[i:i+batch_size]
    
    if i == 0:
        # 첫 번째 배치로 벡터 스토어 생성
        vector_store = PineconeVectorStore.from_documents(
            batch_docs,            # batch_size 수 만큼의 chunk
            embedding=embeddings,  # 임베딩 벡터로 변환
            index_name=PINECONE_INDEX_NAME,   # index 이름
            namespace=PINECONE_NAMESPACE      
        )
    else:
        # 이후 배치는 기존 벡터 스토어에 추가, # 내부적으로 임베딩 벡터로 변환
        vector_store.add_documents(batch_docs)    
    
    print(f"배치 {i//batch_size + 1} 완료: {len(batch_docs)}개 문서 업로드")
# Out:
# 배치 1 완료: 100개 문서 업로드
# 배치 2 완료: 100개 문서 업로드
# 배치 3 완료: 100개 문서 업로드
# 배치 4 완료: 100개 문서 업로드
# 배치 5 완료: 100개 문서 업로드
# 배치 6 완료: 100개 문서 업로드
# 배치 7 완료: 100개 문서 업로드
# 배치 8 완료: 100개 문서 업로드
# 배치 9 완료: 100개 문서 업로드
# 배치 10 완료: 100개 문서 업로드
# 배치 11 완료: 100개 문서 업로드
# 배치 12 완료: 100개 문서 업로드
# 배치 13 완료: 100개 문서 업로드
# 배치 14 완료: 100개 문서 업로드
# 배치 15 완료: 100개 문서 업로드
# 배치 16 완료: 100개 문서 업로드
# 배치 17 완료: 100개 문서 업로드
# 배치 18 완료: 100개 문서 업로드
# 배치 19 완료: 100개 문서 업로드
# 배치 343 완료: 100개 문서 업로드
# 배치 344 완료: 100개 문서 업로드
# 배치 345 완료: 100개 문서 업로드
# 배치 346 완료: 100개 문서 업로드
# 배치 347 완료: 100개 문서 업로드
# 배치 348 완료: 100개 문서 업로드
# 배치 349 완료: 100개 문서 업로드
# 배치 350 완료: 100개 문서 업로드
# 배치 351 완료: 100개 문서 업로드
# 배치 352 완료: 100개 문서 업로드
# 배치 353 완료: 100개 문서 업로드
# 배치 354 완료: 100개 문서 업로드
# 배치 355 완료: 100개 문서 업로드
# 배치 356 완료: 100개 문서 업로드
# 배치 357 완료: 100개 문서 업로드
# 배치 358 완료: 100개 문서 업로드
# 배치 359 완료: 100개 문서 업로드
# 배치 360 완료: 100개 문서 업로드
# 배치 361 완료: 100개 문서 업로드
# 배치 362 완료: 100개 문서 업로드
# 배치 363 완료: 100개 문서 업로드
# 배치 364 완료: 100개 문서 업로드
# 배치 365 완료: 100개 문서 업로드
# 배치 366 완료: 100개 문서 업로드
# 배치 367 완료: 100개 문서 업로드
# 배치 368 완료: 100개 문서 업로드
# 배치 369 완료: 100개 문서 업로드
# 배치 370 완료: 100개 문서 업로드
# 배치 371 완료: 100개 문서 업로드
# 배치 372 완료: 100개 문서 업로드
# 배치 373 완료: 100개 문서 업로드
# 배치 374 완료: 100개 문서 업로드
# 배치 375 완료: 100개 문서 업로드
# 배치 376 완료: 100개 문서 업로드
# 배치 377 완료: 100개 문서 업로드
# 배치 378 완료: 100개 문서 업로드
# 배치 379 완료: 100개 문서 업로드
# 배치 380 완료: 100개 문서 업로드
# 배치 381 완료: 100개 문서 업로드
# 배치 382 완료: 100개 문서 업로드
# 배치 383 완료: 100개 문서 업로드
# 배치 384 완료: 100개 문서 업로드
# 배치 385 완료: 100개 문서 업로드
# 배치 386 완료: 100개 문서 업로드
# 배치 387 완료: 100개 문서 업로드
# 배치 388 완료: 100개 문서 업로드
# 배치 389 완료: 100개 문서 업로드
# 배치 390 완료: 100개 문서 업로드
# 배치 391 완료: 100개 문서 업로드
# 배치 392 완료: 100개 문서 업로드
# 배치 393 완료: 100개 문서 업로드
# 배치 394 완료: 100개 문서 업로드
# 배치 395 완료: 100개 문서 업로드
# 배치 396 완료: 100개 문서 업로드
# 배치 397 완료: 100개 문서 업로드
# 배치 398 완료: 100개 문서 업로드
# 배치 399 완료: 100개 문서 업로드
# 배치 400 완료: 100개 문서 업로드
# 배치 401 완료: 100개 문서 업로드
# 배치 402 완료: 100개 문서 업로드
# 배치 403 완료: 100개 문서 업로드
# 배치 404 완료: 100개 문서 업로드
# 배치 405 완료: 100개 문서 업로드
# 배치 406 완료: 100개 문서 업로드
# 배치 407 완료: 100개 문서 업로드
# 배치 408 완료: 100개 문서 업로드
# 배치 409 완료: 100개 문서 업로드
# 배치 410 완료: 100개 문서 업로드
# 배치 411 완료: 100개 문서 업로드
# 배치 412 완료: 100개 문서 업로드
# 배치 413 완료: 100개 문서 업로드
# 배치 414 완료: 100개 문서 업로드
# 배치 415 완료: 100개 문서 업로드
# 배치 416 완료: 100개 문서 업로드
# 배치 417 완료: 100개 문서 업로드
# 배치 418 완료: 100개 문서 업로드
# 배치 419 완료: 100개 문서 업로드
# 배치 420 완료: 100개 문서 업로드
# 배치 421 완료: 100개 문서 업로드
# 배치 422 완료: 100개 문서 업로드
# 배치 423 완료: 100개 문서 업로드
# 배치 424 완료: 100개 문서 업로드
# 배치 425 완료: 100개 문서 업로드
# 배치 426 완료: 100개 문서 업로드
# 배치 427 완료: 100개 문서 업로드
# 배치 428 완료: 100개 문서 업로드
# 배치 429 완료: 100개 문서 업로드
# 배치 430 완료: 100개 문서 업로드
# 배치 431 완료: 100개 문서 업로드
# 배치 432 완료: 100개 문서 업로드
# 배치 433 완료: 100개 문서 업로드
# 배치 434 완료: 100개 문서 업로드
# 배치 435 완료: 100개 문서 업로드
# 배치 436 완료: 100개 문서 업로드
# 배치 437 완료: 100개 문서 업로드
# 배치 438 완료: 100개 문서 업로드
# 배치 439 완료: 100개 문서 업로드
# 배치 440 완료: 100개 문서 업로드
# 배치 441 완료: 100개 문서 업로드
# 배치 442 완료: 100개 문서 업로드
# 배치 443 완료: 100개 문서 업로드
# 배치 444 완료: 100개 문서 업로드
# 배치 445 완료: 100개 문서 업로드
# 배치 446 완료: 100개 문서 업로드
# 배치 447 완료: 100개 문서 업로드
# 배치 448 완료: 100개 문서 업로드
# 배치 449 완료: 100개 문서 업로드
# 배치 450 완료: 100개 문서 업로드
# 배치 451 완료: 100개 문서 업로드
# 배치 452 완료: 100개 문서 업로드
# 배치 453 완료: 100개 문서 업로드
# 배치 454 완료: 100개 문서 업로드
# 배치 455 완료: 100개 문서 업로드
# 배치 456 완료: 100개 문서 업로드
# 배치 457 완료: 100개 문서 업로드
# 배치 458 완료: 100개 문서 업로드
# 배치 459 완료: 100개 문서 업로드
# 배치 460 완료: 100개 문서 업로드
# 배치 461 완료: 100개 문서 업로드
# 배치 462 완료: 100개 문서 업로드
# 배치 463 완료: 100개 문서 업로드
# 배치 464 완료: 100개 문서 업로드
# 배치 465 완료: 100개 문서 업로드
# 배치 466 완료: 100개 문서 업로드
# 배치 467 완료: 100개 문서 업로드
# 배치 468 완료: 100개 문서 업로드
# 배치 469 완료: 100개 문서 업로드
# 배치 470 완료: 100개 문서 업로드
# 배치 471 완료: 100개 문서 업로드
# 배치 472 완료: 100개 문서 업로드
# 배치 473 완료: 100개 문서 업로드
# 배치 474 완료: 100개 문서 업로드
# 배치 475 완료: 100개 문서 업로드
# 배치 476 완료: 100개 문서 업로드
# 배치 477 완료: 100개 문서 업로드
# 배치 478 완료: 100개 문서 업로드
# 배치 479 완료: 100개 문서 업로드
# 배치 480 완료: 100개 문서 업로드
# 배치 481 완료: 100개 문서 업로드
# 배치 482 완료: 100개 문서 업로드
# 배치 483 완료: 100개 문서 업로드
# 배치 484 완료: 100개 문서 업로드
# 배치 485 완료: 100개 문서 업로드
# 배치 486 완료: 100개 문서 업로드
# 배치 487 완료: 100개 문서 업로드
# 배치 488 완료: 100개 문서 업로드
# 배치 489 완료: 100개 문서 업로드
# 배치 490 완료: 100개 문서 업로드
# 배치 491 완료: 100개 문서 업로드
# 배치 492 완료: 100개 문서 업로드
# 배치 493 완료: 100개 문서 업로드
# 배치 494 완료: 100개 문서 업로드
# 배치 495 완료: 100개 문서 업로드
# 배치 496 완료: 100개 문서 업로드
# 배치 497 완료: 100개 문서 업로드
# 배치 498 완료: 100개 문서 업로드
# 배치 499 완료: 100개 문서 업로드
# 배치 500 완료: 100개 문서 업로드
# 배치 501 완료: 100개 문서 업로드
# 배치 502 완료: 100개 문서 업로드
# 배치 503 완료: 100개 문서 업로드
# 배치 504 완료: 100개 문서 업로드
# 배치 505 완료: 100개 문서 업로드
# 배치 506 완료: 100개 문서 업로드
# 배치 507 완료: 100개 문서 업로드
# 배치 508 완료: 100개 문서 업로드
# 배치 509 완료: 100개 문서 업로드
# 배치 510 완료: 100개 문서 업로드
# 배치 511 완료: 100개 문서 업로드
# 배치 512 완료: 100개 문서 업로드
# 배치 513 완료: 100개 문서 업로드
# 배치 514 완료: 100개 문서 업로드
# 배치 515 완료: 100개 문서 업로드
# 배치 516 완료: 100개 문서 업로드
# 배치 517 완료: 100개 문서 업로드
# 배치 518 완료: 100개 문서 업로드
# 배치 519 완료: 100개 문서 업로드
# 배치 520 완료: 100개 문서 업로드
# 배치 521 완료: 100개 문서 업로드
# 배치 522 완료: 100개 문서 업로드
# 배치 523 완료: 100개 문서 업로드
# 배치 524 완료: 100개 문서 업로드
# 배치 525 완료: 100개 문서 업로드
# 배치 526 완료: 100개 문서 업로드
# 배치 527 완료: 100개 문서 업로드
# 배치 528 완료: 100개 문서 업로드
# 배치 529 완료: 100개 문서 업로드
# 배치 530 완료: 100개 문서 업로드
# 배치 531 완료: 100개 문서 업로드
# 배치 532 완료: 100개 문서 업로드
# 배치 533 완료: 100개 문서 업로드
# 배치 534 완료: 100개 문서 업로드
# 배치 535 완료: 100개 문서 업로드
# 배치 536 완료: 100개 문서 업로드
# 배치 537 완료: 100개 문서 업로드
# 배치 538 완료: 100개 문서 업로드
# 배치 539 완료: 100개 문서 업로드
# 배치 540 완료: 100개 문서 업로드
# 배치 541 완료: 100개 문서 업로드
# 배치 542 완료: 100개 문서 업로드
# 배치 543 완료: 100개 문서 업로드
# 배치 544 완료: 100개 문서 업로드
# 배치 545 완료: 100개 문서 업로드
# 배치 546 완료: 100개 문서 업로드
# 배치 547 완료: 100개 문서 업로드
# 배치 548 완료: 100개 문서 업로드
# 배치 549 완료: 100개 문서 업로드
# 배치 550 완료: 100개 문서 업로드
# 배치 551 완료: 100개 문서 업로드
# 배치 552 완료: 100개 문서 업로드
# 배치 553 완료: 100개 문서 업로드
# 배치 554 완료: 100개 문서 업로드
# 배치 555 완료: 100개 문서 업로드
# 배치 556 완료: 100개 문서 업로드
# 배치 557 완료: 100개 문서 업로드
# 배치 558 완료: 100개 문서 업로드
# 배치 559 완료: 100개 문서 업로드
# 배치 560 완료: 100개 문서 업로드
# 배치 561 완료: 100개 문서 업로드
# 배치 562 완료: 100개 문서 업로드
# 배치 563 완료: 100개 문서 업로드
# 배치 564 완료: 100개 문서 업로드
# 배치 565 완료: 100개 문서 업로드
# 배치 566 완료: 100개 문서 업로드
# 배치 567 완료: 100개 문서 업로드
# 배치 568 완료: 100개 문서 업로드
# 배치 569 완료: 100개 문서 업로드
# 배치 570 완료: 100개 문서 업로드
# 배치 571 완료: 100개 문서 업로드
# 배치 572 완료: 100개 문서 업로드
# 배치 573 완료: 100개 문서 업로드
# 배치 574 완료: 100개 문서 업로드
# 배치 575 완료: 100개 문서 업로드
# 배치 576 완료: 100개 문서 업로드
# 배치 577 완료: 100개 문서 업로드
# 배치 578 완료: 100개 문서 업로드
# 배치 579 완료: 100개 문서 업로드
# 배치 580 완료: 100개 문서 업로드
# 배치 581 완료: 100개 문서 업로드
# 배치 582 완료: 100개 문서 업로드
# 배치 583 완료: 100개 문서 업로드
# 배치 584 완료: 100개 문서 업로드
# 배치 585 완료: 100개 문서 업로드
# 배치 586 완료: 100개 문서 업로드
# 배치 587 완료: 100개 문서 업로드
# 배치 588 완료: 100개 문서 업로드
# 배치 589 완료: 100개 문서 업로드
# 배치 590 완료: 100개 문서 업로드
# 배치 591 완료: 100개 문서 업로드
# 배치 592 완료: 100개 문서 업로드
# 배치 593 완료: 100개 문서 업로드
# 배치 594 완료: 100개 문서 업로드
# 배치 595 완료: 100개 문서 업로드
# 배치 596 완료: 100개 문서 업로드
# 배치 597 완료: 100개 문서 업로드
# 배치 598 완료: 100개 문서 업로드
# 배치 599 완료: 100개 문서 업로드
# 배치 600 완료: 100개 문서 업로드
# 배치 601 완료: 100개 문서 업로드
# 배치 602 완료: 100개 문서 업로드
# 배치 603 완료: 100개 문서 업로드
# 배치 604 완료: 100개 문서 업로드
# 배치 605 완료: 100개 문서 업로드
# 배치 606 완료: 100개 문서 업로드
# 배치 607 완료: 100개 문서 업로드
# 배치 608 완료: 100개 문서 업로드
# 배치 609 완료: 100개 문서 업로드
# 배치 610 완료: 100개 문서 업로드
# 배치 611 완료: 100개 문서 업로드
# 배치 612 완료: 100개 문서 업로드
# 배치 613 완료: 100개 문서 업로드
# 배치 614 완료: 100개 문서 업로드
# 배치 615 완료: 100개 문서 업로드
# 배치 616 완료: 100개 문서 업로드
# 배치 617 완료: 100개 문서 업로드
# 배치 618 완료: 100개 문서 업로드
# 배치 619 완료: 100개 문서 업로드
# 배치 620 완료: 100개 문서 업로드
# 배치 621 완료: 100개 문서 업로드
# 배치 622 완료: 100개 문서 업로드
# 배치 623 완료: 100개 문서 업로드
# 배치 624 완료: 100개 문서 업로드
# 배치 625 완료: 100개 문서 업로드
# 배치 626 완료: 100개 문서 업로드
# 배치 627 완료: 100개 문서 업로드
# 배치 628 완료: 100개 문서 업로드
# 배치 629 완료: 100개 문서 업로드
# 배치 630 완료: 100개 문서 업로드
# 배치 631 완료: 100개 문서 업로드
# 배치 632 완료: 100개 문서 업로드
# 배치 633 완료: 100개 문서 업로드
# 배치 634 완료: 100개 문서 업로드
# 배치 635 완료: 100개 문서 업로드
# 배치 636 완료: 100개 문서 업로드
# 배치 637 완료: 100개 문서 업로드
# 배치 638 완료: 100개 문서 업로드
# 배치 639 완료: 100개 문서 업로드
# 배치 640 완료: 100개 문서 업로드
# 배치 641 완료: 100개 문서 업로드
# 배치 642 완료: 100개 문서 업로드
# 배치 643 완료: 100개 문서 업로드
# 배치 644 완료: 100개 문서 업로드
# 배치 645 완료: 100개 문서 업로드
# 배치 646 완료: 100개 문서 업로드
# 배치 647 완료: 100개 문서 업로드
# 배치 648 완료: 100개 문서 업로드
# 배치 649 완료: 100개 문서 업로드
# 배치 650 완료: 100개 문서 업로드
# 배치 651 완료: 100개 문서 업로드
# 배치 652 완료: 100개 문서 업로드
# 배치 653 완료: 100개 문서 업로드
# 배치 654 완료: 100개 문서 업로드
# 배치 655 완료: 100개 문서 업로드
# 배치 656 완료: 100개 문서 업로드
# 배치 657 완료: 100개 문서 업로드
# 배치 658 완료: 100개 문서 업로드
# 배치 659 완료: 100개 문서 업로드
# 배치 660 완료: 100개 문서 업로드
# 배치 661 완료: 100개 문서 업로드
# 배치 662 완료: 100개 문서 업로드
# 배치 663 완료: 100개 문서 업로드
# 배치 664 완료: 100개 문서 업로드
# 배치 665 완료: 100개 문서 업로드
# 배치 666 완료: 100개 문서 업로드
# 배치 667 완료: 100개 문서 업로드
# 배치 668 완료: 100개 문서 업로드
# 배치 669 완료: 100개 문서 업로드
# 배치 670 완료: 100개 문서 업로드
# 배치 671 완료: 100개 문서 업로드
# 배치 672 완료: 100개 문서 업로드
# 배치 673 완료: 100개 문서 업로드
# 배치 674 완료: 100개 문서 업로드
# 배치 675 완료: 100개 문서 업로드
# 배치 676 완료: 100개 문서 업로드
# 배치 677 완료: 100개 문서 업로드
# 배치 678 완료: 100개 문서 업로드
# 배치 679 완료: 100개 문서 업로드
# 배치 680 완료: 100개 문서 업로드
# 배치 681 완료: 100개 문서 업로드
# 배치 682 완료: 100개 문서 업로드
# 배치 683 완료: 100개 문서 업로드
# 배치 684 완료: 100개 문서 업로드
# 배치 685 완료: 100개 문서 업로드
# 배치 686 완료: 100개 문서 업로드
# 배치 687 완료: 100개 문서 업로드
# 배치 688 완료: 100개 문서 업로드
# 배치 689 완료: 100개 문서 업로드
# 배치 690 완료: 100개 문서 업로드
# 배치 691 완료: 100개 문서 업로드
# 배치 692 완료: 100개 문서 업로드
# 배치 693 완료: 100개 문서 업로드
# 배치 694 완료: 100개 문서 업로드
# 배치 695 완료: 100개 문서 업로드
# 배치 696 완료: 100개 문서 업로드
# 배치 697 완료: 100개 문서 업로드
# 배치 698 완료: 100개 문서 업로드
# 배치 699 완료: 100개 문서 업로드
# 배치 700 완료: 100개 문서 업로드
# 배치 701 완료: 100개 문서 업로드
# 배치 702 완료: 100개 문서 업로드
# 배치 703 완료: 100개 문서 업로드
# 배치 704 완료: 100개 문서 업로드
# 배치 705 완료: 100개 문서 업로드
# 배치 706 완료: 100개 문서 업로드
# 배치 707 완료: 100개 문서 업로드
# 배치 708 완료: 100개 문서 업로드
# 배치 709 완료: 100개 문서 업로드
# 배치 710 완료: 100개 문서 업로드
# 배치 711 완료: 100개 문서 업로드
# 배치 712 완료: 100개 문서 업로드
# 배치 713 완료: 100개 문서 업로드
# 배치 714 완료: 100개 문서 업로드
# 배치 715 완료: 100개 문서 업로드
# 배치 716 완료: 100개 문서 업로드
# 배치 717 완료: 100개 문서 업로드
# 배치 718 완료: 100개 문서 업로드
# 배치 719 완료: 100개 문서 업로드
# 배치 720 완료: 100개 문서 업로드
# 배치 721 완료: 100개 문서 업로드
# 배치 722 완료: 100개 문서 업로드
# 배치 723 완료: 100개 문서 업로드
# 배치 724 완료: 100개 문서 업로드
# 배치 725 완료: 100개 문서 업로드
# 배치 726 완료: 100개 문서 업로드
# 배치 727 완료: 100개 문서 업로드
# 배치 728 완료: 100개 문서 업로드
# 배치 729 완료: 100개 문서 업로드
# 배치 730 완료: 100개 문서 업로드
# 배치 731 완료: 100개 문서 업로드
# 배치 732 완료: 100개 문서 업로드
# 배치 733 완료: 100개 문서 업로드
# 배치 734 완료: 100개 문서 업로드
# 배치 735 완료: 100개 문서 업로드
# 배치 736 완료: 100개 문서 업로드
# 배치 737 완료: 100개 문서 업로드
# 배치 738 완료: 100개 문서 업로드
# 배치 739 완료: 100개 문서 업로드
# 배치 740 완료: 100개 문서 업로드
# 배치 741 완료: 100개 문서 업로드
# 배치 742 완료: 100개 문서 업로드
# 배치 743 완료: 100개 문서 업로드
# 배치 744 완료: 100개 문서 업로드
# 배치 745 완료: 100개 문서 업로드
# 배치 746 완료: 100개 문서 업로드
# 배치 747 완료: 100개 문서 업로드
# 배치 748 완료: 100개 문서 업로드
# 배치 749 완료: 100개 문서 업로드
# 배치 750 완료: 100개 문서 업로드
# 배치 751 완료: 100개 문서 업로드
# 배치 752 완료: 100개 문서 업로드
# 배치 753 완료: 100개 문서 업로드
# 배치 754 완료: 100개 문서 업로드
# 배치 755 완료: 100개 문서 업로드
# 배치 756 완료: 100개 문서 업로드
# 배치 757 완료: 100개 문서 업로드
# 배치 758 완료: 100개 문서 업로드
# 배치 759 완료: 100개 문서 업로드
# 배치 760 완료: 100개 문서 업로드
# 배치 761 완료: 100개 문서 업로드
# 배치 762 완료: 100개 문서 업로드
# 배치 763 완료: 100개 문서 업로드
# 배치 764 완료: 100개 문서 업로드
# 배치 765 완료: 100개 문서 업로드
# 배치 766 완료: 100개 문서 업로드
# 배치 767 완료: 100개 문서 업로드
# 배치 768 완료: 100개 문서 업로드
# 배치 769 완료: 100개 문서 업로드
# 배치 770 완료: 100개 문서 업로드
# 배치 771 완료: 100개 문서 업로드
# 배치 772 완료: 100개 문서 업로드
# 배치 773 완료: 100개 문서 업로드
# 배치 774 완료: 100개 문서 업로드
# 배치 775 완료: 100개 문서 업로드
# 배치 776 완료: 100개 문서 업로드
# 배치 777 완료: 100개 문서 업로드
# 배치 778 완료: 100개 문서 업로드
# 배치 779 완료: 100개 문서 업로드
# 배치 780 완료: 100개 문서 업로드
# 배치 781 완료: 100개 문서 업로드
# 배치 782 완료: 100개 문서 업로드
# 배치 783 완료: 100개 문서 업로드
# 배치 784 완료: 100개 문서 업로드
# 배치 785 완료: 100개 문서 업로드
# 배치 786 완료: 100개 문서 업로드
# 배치 787 완료: 100개 문서 업로드
# 배치 788 완료: 100개 문서 업로드
# 배치 789 완료: 100개 문서 업로드
# 배치 790 완료: 100개 문서 업로드
# 배치 791 완료: 100개 문서 업로드
# 배치 792 완료: 100개 문서 업로드
# 배치 793 완료: 100개 문서 업로드
# 배치 794 완료: 100개 문서 업로드
# 배치 795 완료: 100개 문서 업로드
# 배치 796 완료: 100개 문서 업로드
# 배치 797 완료: 100개 문서 업로드
# 배치 798 완료: 100개 문서 업로드
# 배치 799 완료: 100개 문서 업로드
# 배치 800 완료: 100개 문서 업로드
# 배치 801 완료: 100개 문서 업로드
# 배치 802 완료: 100개 문서 업로드
# 배치 803 완료: 100개 문서 업로드
# 배치 804 완료: 100개 문서 업로드
# 배치 805 완료: 100개 문서 업로드
# 배치 806 완료: 100개 문서 업로드
# 배치 807 완료: 100개 문서 업로드
# 배치 808 완료: 100개 문서 업로드
# 배치 809 완료: 100개 문서 업로드
# 배치 810 완료: 100개 문서 업로드
# 배치 811 완료: 100개 문서 업로드
# 배치 812 완료: 100개 문서 업로드
# 배치 813 완료: 100개 문서 업로드
# 배치 814 완료: 100개 문서 업로드
# 배치 815 완료: 100개 문서 업로드
# 배치 816 완료: 100개 문서 업로드
# 배치 817 완료: 100개 문서 업로드
# 배치 818 완료: 100개 문서 업로드
# 배치 819 완료: 100개 문서 업로드
# 배치 820 완료: 100개 문서 업로드
# 배치 821 완료: 100개 문서 업로드
# 배치 822 완료: 100개 문서 업로드
# 배치 823 완료: 100개 문서 업로드
# 배치 824 완료: 100개 문서 업로드
# 배치 825 완료: 100개 문서 업로드
# 배치 826 완료: 100개 문서 업로드
# 배치 827 완료: 100개 문서 업로드
# 배치 828 완료: 100개 문서 업로드
# 배치 829 완료: 100개 문서 업로드
# 배치 830 완료: 100개 문서 업로드
# 배치 831 완료: 100개 문서 업로드
# 배치 832 완료: 100개 문서 업로드
# 배치 833 완료: 100개 문서 업로드
# 배치 834 완료: 100개 문서 업로드
# 배치 835 완료: 100개 문서 업로드
# 배치 836 완료: 100개 문서 업로드
# 배치 837 완료: 100개 문서 업로드
# 배치 838 완료: 100개 문서 업로드
# 배치 839 완료: 100개 문서 업로드
# 배치 840 완료: 100개 문서 업로드
# 배치 841 완료: 100개 문서 업로드
# 배치 842 완료: 100개 문서 업로드
# 배치 843 완료: 100개 문서 업로드
# 배치 844 완료: 100개 문서 업로드
# 배치 845 완료: 100개 문서 업로드
# 배치 846 완료: 100개 문서 업로드
# 배치 847 완료: 100개 문서 업로드
# 배치 848 완료: 100개 문서 업로드
# 배치 849 완료: 100개 문서 업로드
# 배치 850 완료: 100개 문서 업로드
# 배치 851 완료: 100개 문서 업로드
# 배치 852 완료: 100개 문서 업로드
# 배치 853 완료: 100개 문서 업로드
# 배치 854 완료: 100개 문서 업로드
# 배치 855 완료: 100개 문서 업로드
# 배치 856 완료: 100개 문서 업로드
# 배치 857 완료: 100개 문서 업로드
# 배치 858 완료: 100개 문서 업로드
# 배치 859 완료: 100개 문서 업로드
# 배치 860 완료: 100개 문서 업로드
# 배치 861 완료: 100개 문서 업로드
# 배치 862 완료: 100개 문서 업로드
# 배치 863 완료: 100개 문서 업로드
# 배치 864 완료: 100개 문서 업로드
# 배치 865 완료: 100개 문서 업로드
# 배치 866 완료: 100개 문서 업로드
# 배치 867 완료: 100개 문서 업로드
# 배치 868 완료: 100개 문서 업로드
# 배치 869 완료: 100개 문서 업로드
# 배치 870 완료: 100개 문서 업로드
# 배치 871 완료: 100개 문서 업로드
# 배치 872 완료: 100개 문서 업로드
# 배치 873 완료: 100개 문서 업로드
# 배치 874 완료: 100개 문서 업로드
# 배치 875 완료: 100개 문서 업로드
# 배치 876 완료: 100개 문서 업로드
# 배치 877 완료: 100개 문서 업로드
# 배치 878 완료: 100개 문서 업로드
# 배치 879 완료: 100개 문서 업로드
# 배치 880 완료: 100개 문서 업로드
# 배치 881 완료: 100개 문서 업로드
# 배치 882 완료: 100개 문서 업로드
# 배치 883 완료: 100개 문서 업로드
# 배치 884 완료: 100개 문서 업로드
# 배치 885 완료: 100개 문서 업로드
# 배치 886 완료: 100개 문서 업로드
# 배치 887 완료: 100개 문서 업로드
# 배치 888 완료: 100개 문서 업로드
# 배치 889 완료: 100개 문서 업로드
# 배치 890 완료: 100개 문서 업로드
# 배치 891 완료: 100개 문서 업로드
# 배치 892 완료: 100개 문서 업로드
# 배치 893 완료: 100개 문서 업로드
# 배치 894 완료: 100개 문서 업로드
# 배치 895 완료: 100개 문서 업로드
# 배치 896 완료: 100개 문서 업로드
# 배치 897 완료: 100개 문서 업로드
# 배치 898 완료: 100개 문서 업로드
# 배치 899 완료: 100개 문서 업로드
# 배치 900 완료: 100개 문서 업로드
# 배치 901 완료: 100개 문서 업로드
# 배치 902 완료: 100개 문서 업로드
# 배치 903 완료: 100개 문서 업로드
# 배치 904 완료: 100개 문서 업로드
# 배치 905 완료: 100개 문서 업로드
# 배치 906 완료: 100개 문서 업로드
# 배치 907 완료: 100개 문서 업로드
# 배치 908 완료: 100개 문서 업로드
# 배치 909 완료: 100개 문서 업로드
# 배치 910 완료: 100개 문서 업로드
# 배치 911 완료: 100개 문서 업로드
# 배치 912 완료: 100개 문서 업로드
# 배치 913 완료: 100개 문서 업로드
# 배치 914 완료: 100개 문서 업로드
# 배치 915 완료: 100개 문서 업로드
# 배치 916 완료: 100개 문서 업로드
# 배치 917 완료: 100개 문서 업로드
# 배치 918 완료: 100개 문서 업로드
# 배치 919 완료: 100개 문서 업로드
# 배치 920 완료: 100개 문서 업로드
# 배치 921 완료: 100개 문서 업로드
# 배치 922 완료: 100개 문서 업로드
# 배치 923 완료: 100개 문서 업로드
# 배치 924 완료: 100개 문서 업로드
# 배치 925 완료: 100개 문서 업로드
# 배치 926 완료: 100개 문서 업로드
# 배치 927 완료: 100개 문서 업로드
# 배치 928 완료: 100개 문서 업로드
# 배치 929 완료: 100개 문서 업로드
# 배치 930 완료: 100개 문서 업로드
# 배치 931 완료: 100개 문서 업로드
# 배치 932 완료: 100개 문서 업로드
# 배치 933 완료: 100개 문서 업로드
# 배치 934 완료: 100개 문서 업로드
# 배치 935 완료: 100개 문서 업로드
# 배치 936 완료: 100개 문서 업로드
# 배치 937 완료: 100개 문서 업로드
# 배치 938 완료: 100개 문서 업로드
# 배치 939 완료: 100개 문서 업로드
# 배치 940 완료: 100개 문서 업로드
# 배치 941 완료: 100개 문서 업로드
# 배치 942 완료: 100개 문서 업로드
# 배치 943 완료: 100개 문서 업로드
# 배치 944 완료: 100개 문서 업로드
# 배치 945 완료: 100개 문서 업로드
# 배치 946 완료: 100개 문서 업로드
# 배치 947 완료: 100개 문서 업로드
# 배치 948 완료: 100개 문서 업로드
# 배치 949 완료: 100개 문서 업로드
# 배치 950 완료: 100개 문서 업로드
# 배치 951 완료: 100개 문서 업로드
# 배치 952 완료: 100개 문서 업로드
# 배치 953 완료: 100개 문서 업로드
# 배치 954 완료: 100개 문서 업로드
# 배치 955 완료: 100개 문서 업로드
# 배치 956 완료: 100개 문서 업로드
# 배치 957 완료: 100개 문서 업로드
# 배치 958 완료: 100개 문서 업로드
# 배치 959 완료: 100개 문서 업로드
# 배치 960 완료: 100개 문서 업로드
# 배치 961 완료: 100개 문서 업로드
# 배치 962 완료: 100개 문서 업로드
# 배치 963 완료: 100개 문서 업로드
# 배치 964 완료: 100개 문서 업로드
# 배치 965 완료: 100개 문서 업로드
# 배치 966 완료: 100개 문서 업로드
# 배치 967 완료: 100개 문서 업로드
# 배치 968 완료: 100개 문서 업로드
# 배치 969 완료: 100개 문서 업로드
# 배치 970 완료: 100개 문서 업로드
# 배치 971 완료: 100개 문서 업로드
# 배치 972 완료: 100개 문서 업로드
# 배치 973 완료: 100개 문서 업로드
# 배치 974 완료: 100개 문서 업로드
# 배치 975 완료: 100개 문서 업로드
# 배치 976 완료: 100개 문서 업로드
# 배치 977 완료: 100개 문서 업로드
# 배치 978 완료: 100개 문서 업로드
# 배치 979 완료: 100개 문서 업로드
# 배치 980 완료: 100개 문서 업로드
# 배치 981 완료: 100개 문서 업로드
# 배치 982 완료: 100개 문서 업로드
# 배치 983 완료: 100개 문서 업로드
# 배치 984 완료: 100개 문서 업로드
# 배치 985 완료: 100개 문서 업로드
# 배치 986 완료: 100개 문서 업로드
# 배치 987 완료: 100개 문서 업로드
# 배치 988 완료: 100개 문서 업로드
# 배치 989 완료: 100개 문서 업로드
# 배치 990 완료: 100개 문서 업로드
# 배치 991 완료: 100개 문서 업로드
# 배치 992 완료: 100개 문서 업로드
# 배치 993 완료: 100개 문서 업로드
# 배치 994 완료: 100개 문서 업로드
# 배치 995 완료: 100개 문서 업로드
# 배치 996 완료: 100개 문서 업로드
# 배치 997 완료: 100개 문서 업로드
# 배치 998 완료: 100개 문서 업로드
# 배치 999 완료: 100개 문서 업로드
# 배치 1000 완료: 100개 문서 업로드
# 배치 1001 완료: 100개 문서 업로드
# 배치 1002 완료: 100개 문서 업로드
# 배치 1003 완료: 100개 문서 업로드
# 배치 1004 완료: 100개 문서 업로드
# 배치 1005 완료: 100개 문서 업로드
# 배치 1006 완료: 100개 문서 업로드
# 배치 1007 완료: 100개 문서 업로드
# 배치 1008 완료: 100개 문서 업로드
# 배치 1009 완료: 100개 문서 업로드
# 배치 1010 완료: 100개 문서 업로드
# 배치 1011 완료: 100개 문서 업로드
# 배치 1012 완료: 100개 문서 업로드
# 배치 1013 완료: 100개 문서 업로드
# 배치 1014 완료: 100개 문서 업로드
# 배치 1015 완료: 100개 문서 업로드
# 배치 1016 완료: 100개 문서 업로드
# 배치 1017 완료: 100개 문서 업로드
# 배치 1018 완료: 100개 문서 업로드
# 배치 1019 완료: 100개 문서 업로드
# 배치 1020 완료: 100개 문서 업로드
# 배치 1021 완료: 100개 문서 업로드
# 배치 1022 완료: 100개 문서 업로드
# 배치 1023 완료: 100개 문서 업로드
# 배치 1024 완료: 100개 문서 업로드
# 배치 1025 완료: 100개 문서 업로드
# 배치 1026 완료: 100개 문서 업로드
# 배치 1027 완료: 100개 문서 업로드
# 배치 1028 완료: 100개 문서 업로드
# 배치 1029 완료: 100개 문서 업로드
# 배치 1030 완료: 100개 문서 업로드
# 배치 1031 완료: 100개 문서 업로드
# 배치 1032 완료: 100개 문서 업로드
# 배치 1033 완료: 100개 문서 업로드
# 배치 1034 완료: 100개 문서 업로드
# 배치 1035 완료: 100개 문서 업로드
# 배치 1036 완료: 100개 문서 업로드
# 배치 1037 완료: 100개 문서 업로드
# 배치 1038 완료: 100개 문서 업로드
# 배치 1039 완료: 100개 문서 업로드
# 배치 1040 완료: 100개 문서 업로드
# 배치 1041 완료: 100개 문서 업로드
# 배치 1042 완료: 100개 문서 업로드
# 배치 1043 완료: 100개 문서 업로드
# 배치 1044 완료: 100개 문서 업로드
# 배치 1045 완료: 100개 문서 업로드
# 배치 1046 완료: 100개 문서 업로드
# 배치 1047 완료: 100개 문서 업로드
# 배치 1048 완료: 100개 문서 업로드
# 배치 1049 완료: 100개 문서 업로드
# 배치 1050 완료: 100개 문서 업로드
# 배치 1051 완료: 100개 문서 업로드
# 배치 1052 완료: 100개 문서 업로드
# 배치 1053 완료: 100개 문서 업로드
# 배치 1054 완료: 100개 문서 업로드
# 배치 1055 완료: 100개 문서 업로드
# 배치 1056 완료: 100개 문서 업로드
# 배치 1057 완료: 100개 문서 업로드
# 배치 1058 완료: 100개 문서 업로드
# 배치 1059 완료: 100개 문서 업로드
# 배치 1060 완료: 100개 문서 업로드
# 배치 1061 완료: 100개 문서 업로드
# 배치 1062 완료: 100개 문서 업로드
# 배치 1063 완료: 100개 문서 업로드
# 배치 1064 완료: 100개 문서 업로드
# 배치 1065 완료: 100개 문서 업로드
# 배치 1066 완료: 100개 문서 업로드
# 배치 1067 완료: 100개 문서 업로드
# 배치 1068 완료: 100개 문서 업로드
# 배치 1069 완료: 100개 문서 업로드
# 배치 1070 완료: 100개 문서 업로드
# 배치 1071 완료: 100개 문서 업로드
# 배치 1072 완료: 100개 문서 업로드
# 배치 1073 완료: 100개 문서 업로드
# 배치 1074 완료: 100개 문서 업로드
# 배치 1075 완료: 100개 문서 업로드
# 배치 1076 완료: 100개 문서 업로드
# 배치 1077 완료: 100개 문서 업로드
# 배치 1078 완료: 100개 문서 업로드
# 배치 1079 완료: 100개 문서 업로드
# 배치 1080 완료: 100개 문서 업로드
# 배치 1081 완료: 100개 문서 업로드
# 배치 1082 완료: 100개 문서 업로드
# 배치 1083 완료: 100개 문서 업로드
# 배치 1084 완료: 100개 문서 업로드
# 배치 1085 완료: 100개 문서 업로드
# 배치 1086 완료: 100개 문서 업로드
# 배치 1087 완료: 100개 문서 업로드
# 배치 1088 완료: 100개 문서 업로드
# 배치 1089 완료: 100개 문서 업로드
# 배치 1090 완료: 100개 문서 업로드
# 배치 1091 완료: 100개 문서 업로드
# 배치 1092 완료: 100개 문서 업로드
# 배치 1093 완료: 100개 문서 업로드
# 배치 1094 완료: 100개 문서 업로드
# 배치 1095 완료: 100개 문서 업로드
# 배치 1096 완료: 100개 문서 업로드
# 배치 1097 완료: 100개 문서 업로드
# 배치 1098 완료: 100개 문서 업로드
# 배치 1099 완료: 100개 문서 업로드
# 배치 1100 완료: 100개 문서 업로드
# 배치 1101 완료: 100개 문서 업로드
# 배치 1102 완료: 100개 문서 업로드
# 배치 1103 완료: 100개 문서 업로드
# 배치 1104 완료: 100개 문서 업로드
# 배치 1105 완료: 100개 문서 업로드
# 배치 1106 완료: 100개 문서 업로드
# 배치 1107 완료: 100개 문서 업로드
# 배치 1108 완료: 100개 문서 업로드
# 배치 1109 완료: 100개 문서 업로드
# 배치 1110 완료: 100개 문서 업로드
# 배치 1111 완료: 100개 문서 업로드
# 배치 1112 완료: 100개 문서 업로드
# 배치 1113 완료: 100개 문서 업로드
# 배치 1114 완료: 100개 문서 업로드
# 배치 1115 완료: 100개 문서 업로드
# 배치 1116 완료: 100개 문서 업로드
# 배치 1117 완료: 100개 문서 업로드
# 배치 1118 완료: 100개 문서 업로드
# 배치 1119 완료: 100개 문서 업로드
# 배치 1120 완료: 100개 문서 업로드
# 배치 1121 완료: 100개 문서 업로드
# 배치 1122 완료: 100개 문서 업로드
# 배치 1123 완료: 100개 문서 업로드
# 배치 1124 완료: 100개 문서 업로드
# 배치 1125 완료: 100개 문서 업로드
# 배치 1126 완료: 100개 문서 업로드
# 배치 1127 완료: 100개 문서 업로드
# 배치 1128 완료: 100개 문서 업로드
# 배치 1129 완료: 100개 문서 업로드
# 배치 1130 완료: 100개 문서 업로드
# 배치 1131 완료: 100개 문서 업로드
# 배치 1132 완료: 100개 문서 업로드
# 배치 1133 완료: 100개 문서 업로드
# 배치 1134 완료: 100개 문서 업로드
# 배치 1135 완료: 100개 문서 업로드
# 배치 1136 완료: 100개 문서 업로드
# 배치 1137 완료: 100개 문서 업로드
# 배치 1138 완료: 100개 문서 업로드
# 배치 1139 완료: 100개 문서 업로드
# 배치 1140 완료: 100개 문서 업로드
# 배치 1141 완료: 100개 문서 업로드
# 배치 1142 완료: 100개 문서 업로드
# 배치 1143 완료: 100개 문서 업로드
# 배치 1144 완료: 100개 문서 업로드
# 배치 1145 완료: 100개 문서 업로드
# 배치 1146 완료: 100개 문서 업로드
# 배치 1147 완료: 100개 문서 업로드
# 배치 1148 완료: 100개 문서 업로드
# 배치 1149 완료: 100개 문서 업로드
# 배치 1150 완료: 100개 문서 업로드
# 배치 1151 완료: 100개 문서 업로드
# 배치 1152 완료: 100개 문서 업로드
# 배치 1153 완료: 100개 문서 업로드
# 배치 1154 완료: 100개 문서 업로드
# 배치 1155 완료: 100개 문서 업로드
# 배치 1156 완료: 100개 문서 업로드
# 배치 1157 완료: 100개 문서 업로드
# 배치 1158 완료: 100개 문서 업로드
# 배치 1159 완료: 100개 문서 업로드
# 배치 1160 완료: 100개 문서 업로드
# 배치 1161 완료: 100개 문서 업로드
# 배치 1162 완료: 100개 문서 업로드
# 배치 1163 완료: 100개 문서 업로드
# 배치 1164 완료: 100개 문서 업로드
# 배치 1165 완료: 100개 문서 업로드
# 배치 1166 완료: 100개 문서 업로드
# 배치 1167 완료: 100개 문서 업로드
# 배치 1168 완료: 100개 문서 업로드
# 배치 1169 완료: 100개 문서 업로드
# 배치 1170 완료: 100개 문서 업로드
# 배치 1171 완료: 100개 문서 업로드
# 배치 1172 완료: 100개 문서 업로드
# 배치 1173 완료: 100개 문서 업로드
# 배치 1174 완료: 100개 문서 업로드
# 배치 1175 완료: 100개 문서 업로드
# 배치 1176 완료: 100개 문서 업로드
# 배치 1177 완료: 100개 문서 업로드
# 배치 1178 완료: 100개 문서 업로드
# 배치 1179 완료: 100개 문서 업로드
# 배치 1180 완료: 100개 문서 업로드
# 배치 1181 완료: 100개 문서 업로드
# 배치 1182 완료: 100개 문서 업로드
# 배치 1183 완료: 100개 문서 업로드
# 배치 1184 완료: 100개 문서 업로드
# 배치 1185 완료: 100개 문서 업로드
# 배치 1186 완료: 100개 문서 업로드
# 배치 1187 완료: 100개 문서 업로드
# 배치 1188 완료: 100개 문서 업로드
# 배치 1189 완료: 100개 문서 업로드
# 배치 1190 완료: 100개 문서 업로드
# 배치 1191 완료: 100개 문서 업로드
# 배치 1192 완료: 100개 문서 업로드
# 배치 1193 완료: 100개 문서 업로드
# 배치 1194 완료: 100개 문서 업로드
# 배치 1195 완료: 100개 문서 업로드
# 배치 1196 완료: 100개 문서 업로드
# 배치 1197 완료: 100개 문서 업로드
# 배치 1198 완료: 100개 문서 업로드
# 배치 1199 완료: 100개 문서 업로드
# 배치 1200 완료: 100개 문서 업로드
# 배치 1201 완료: 100개 문서 업로드
# 배치 1202 완료: 100개 문서 업로드
# 배치 1203 완료: 100개 문서 업로드
# 배치 1204 완료: 100개 문서 업로드
# 배치 1205 완료: 100개 문서 업로드
# 배치 1206 완료: 100개 문서 업로드
# 배치 1207 완료: 100개 문서 업로드
# 배치 1208 완료: 100개 문서 업로드
# 배치 1209 완료: 100개 문서 업로드
# 배치 1210 완료: 100개 문서 업로드
# 배치 1211 완료: 100개 문서 업로드
# 배치 1212 완료: 100개 문서 업로드
# 배치 1213 완료: 100개 문서 업로드
# 배치 1214 완료: 100개 문서 업로드
# 배치 1215 완료: 100개 문서 업로드
# 배치 1216 완료: 100개 문서 업로드
# 배치 1217 완료: 100개 문서 업로드
# 배치 1218 완료: 100개 문서 업로드
# 배치 1219 완료: 100개 문서 업로드
# 배치 1220 완료: 100개 문서 업로드
# 배치 1221 완료: 100개 문서 업로드
# 배치 1222 완료: 100개 문서 업로드
# 배치 1223 완료: 100개 문서 업로드
# 배치 1224 완료: 100개 문서 업로드
# 배치 1225 완료: 100개 문서 업로드
# 배치 1226 완료: 100개 문서 업로드
# 배치 1227 완료: 100개 문서 업로드
# 배치 1228 완료: 100개 문서 업로드
# 배치 1229 완료: 100개 문서 업로드
# 배치 1230 완료: 100개 문서 업로드
# 배치 1231 완료: 100개 문서 업로드
# 배치 1232 완료: 100개 문서 업로드
# 배치 1233 완료: 100개 문서 업로드
# 배치 1234 완료: 100개 문서 업로드
# 배치 1235 완료: 100개 문서 업로드
# 배치 1236 완료: 100개 문서 업로드
# 배치 1237 완료: 100개 문서 업로드
# 배치 1238 완료: 100개 문서 업로드
# 배치 1239 완료: 100개 문서 업로드
# 배치 1240 완료: 100개 문서 업로드
# 배치 1241 완료: 100개 문서 업로드
# 배치 1242 완료: 100개 문서 업로드
# 배치 1243 완료: 100개 문서 업로드
# 배치 1244 완료: 100개 문서 업로드
# 배치 1245 완료: 100개 문서 업로드
# 배치 1246 완료: 100개 문서 업로드
# 배치 1247 완료: 100개 문서 업로드
# 배치 1248 완료: 100개 문서 업로드
# 배치 1249 완료: 100개 문서 업로드
# 배치 1250 완료: 100개 문서 업로드
# 배치 1251 완료: 100개 문서 업로드
# 배치 1252 완료: 100개 문서 업로드
# 배치 1253 완료: 100개 문서 업로드
# 배치 1254 완료: 100개 문서 업로드
# 배치 1255 완료: 100개 문서 업로드
# 배치 1256 완료: 100개 문서 업로드
# 배치 1257 완료: 100개 문서 업로드
# 배치 1258 완료: 100개 문서 업로드
# 배치 1259 완료: 100개 문서 업로드
# 배치 1260 완료: 100개 문서 업로드
# 배치 1261 완료: 100개 문서 업로드
# 배치 1262 완료: 100개 문서 업로드
# 배치 1263 완료: 100개 문서 업로드
# 배치 1264 완료: 100개 문서 업로드
# 배치 1265 완료: 100개 문서 업로드
# 배치 1266 완료: 100개 문서 업로드
# 배치 1267 완료: 100개 문서 업로드
# 배치 1268 완료: 100개 문서 업로드
# 배치 1269 완료: 100개 문서 업로드
# 배치 1270 완료: 100개 문서 업로드
# 배치 1271 완료: 100개 문서 업로드
# 배치 1272 완료: 100개 문서 업로드
# 배치 1273 완료: 100개 문서 업로드
# 배치 1274 완료: 100개 문서 업로드
# 배치 1275 완료: 100개 문서 업로드
# 배치 1276 완료: 100개 문서 업로드
# 배치 1277 완료: 100개 문서 업로드
# 배치 1278 완료: 100개 문서 업로드
# 배치 1279 완료: 100개 문서 업로드
# 배치 1280 완료: 100개 문서 업로드
# 배치 1281 완료: 100개 문서 업로드
# 배치 1282 완료: 100개 문서 업로드
# 배치 1283 완료: 100개 문서 업로드
# 배치 1284 완료: 100개 문서 업로드
# 배치 1285 완료: 100개 문서 업로드
# 배치 1286 완료: 100개 문서 업로드
# 배치 1287 완료: 100개 문서 업로드
# 배치 1288 완료: 100개 문서 업로드
# 배치 1289 완료: 100개 문서 업로드
# 배치 1290 완료: 100개 문서 업로드
# 배치 1291 완료: 100개 문서 업로드
# 배치 1292 완료: 100개 문서 업로드
# 배치 1293 완료: 100개 문서 업로드
# 배치 1294 완료: 100개 문서 업로드
# 배치 1295 완료: 100개 문서 업로드
# 배치 1296 완료: 100개 문서 업로드
# 배치 1297 완료: 100개 문서 업로드
# 배치 1298 완료: 100개 문서 업로드
# 배치 1299 완료: 100개 문서 업로드
# 배치 1300 완료: 82개 문서 업로드
